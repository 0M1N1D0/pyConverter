# %%
import pandas as pd

# %%
df = pd.read_csv("tablas.csv", delimiter=";") # index_col="LONGITUD"

# %%
df
# Out:
#            LONGITUD     NANOMETROS    MICRONES MILIMETROS CENTIMETROS  \
# 0        NANOMETROS              1       0,001   0,000001   0,0000001
# 1          MICRONES           1000           1      0,001      0,0001
# 2        MILIMETROS        1000000        1000          1         0,1
# 3       CENTIMETROS       10000000       10000         10           1
# 4            METROS     1000000000     1000000       1000         100
# 5        KILOMETROS  1000000000000  1000000000    1000000      100000
# 6          PULGADAS       25400000       25400       25,4        2,54
# 7              PIES      304800000      304800      304,8       30,48
# 8            YARDAS      914400000      914400      914,4       94,44
# 9            MILLAS  1609344000000  1609344000    1609344    160934,4
# 10  MILLAS NAUTICAS  1852000000000  1852000000    1852000      185200
#
#          METROS      KILOMETROS           PULGADAS              PIES  \
# ...

# %%
df.head()
# Out:
#       LONGITUD  NANOMETROS MICRONES MILIMETROS CENTIMETROS       METROS  \
# 0   NANOMETROS           1    0,001   0,000001   0,0000001  0,000000001
# 1     MICRONES        1000        1      0,001      0,0001     0,000001
# 2   MILIMETROS     1000000     1000          1         0,1        0,001
# 3  CENTIMETROS    10000000    10000         10           1         0,01
# 4       METROS  1000000000  1000000       1000         100            1
#
#        KILOMETROS           PULGADAS              PIES             YARDAS  \
# 0  0,000000000001  0,000000039370079  0,00000000328084  0,000000001093613
# 1     0,000000001           0,000039          0,000003           0,000001
# 2        0,000001            0,03937          0,003281           0,001094
# 3         0,00001           0,393701          0,032808           0,010936
# 4           0,001           39,37008           3,28084           1,093613
#
#               MILLAS    MILLAS_NAUTICAS
# 0  0,000000000000621   0,00000000000054
# ...

# %%
df.tail()
# Out:
#            LONGITUD     NANOMETROS    MICRONES MILIMETROS CENTIMETROS  \
# 6          PULGADAS       25400000       25400       25,4        2,54
# 7              PIES      304800000      304800      304,8       30,48
# 8            YARDAS      914400000      914400      914,4       94,44
# 9            MILLAS  1609344000000  1609344000    1609344    160934,4
# 10  MILLAS NAUTICAS  1852000000000  1852000000    1852000      185200
#
#       METROS KILOMETROS  PULGADAS      PIES    YARDAS    MILLAS  \
# 6     0,0254   0,000025         1  0,083333  0,027778  0,000016
# 7     0,3048   0,000305        12         1  0,333333  0,000189
# 8     0,9144   0,000914        36         3         1  0,000568
# 9   1609,344   1,609344     63360      5280      1760         1
# 10      1852      1,852  72913,39  6076,115  2025,372  1,150779
#
#    MILLAS_NAUTICAS
# 6         0,000014
# 7         0,000165
# 8         0,000494
# 9         0,868976
# 10               1

# %%
df.head(3)
# Out:
#      LONGITUD  NANOMETROS MICRONES MILIMETROS CENTIMETROS       METROS  \
# 0  NANOMETROS           1    0,001   0,000001   0,0000001  0,000000001
# 1    MICRONES        1000        1      0,001      0,0001     0,000001
# 2  MILIMETROS     1000000     1000          1         0,1        0,001
#
#        KILOMETROS           PULGADAS              PIES             YARDAS  \
# 0  0,000000000001  0,000000039370079  0,00000000328084  0,000000001093613
# 1     0,000000001           0,000039          0,000003           0,000001
# 2        0,000001            0,03937          0,003281           0,001094
#
#               MILLAS    MILLAS_NAUTICAS
# 0  0,000000000000621   0,00000000000054
# 1  0,000000000621371  0,000000000539957
# 2  0,000000621371192  0,000000539956803

# %%
df.describe()
# Out:
#          NANOMETROS
# count  1.100000e+01
# mean   4.057818e+11
# std    7.217095e+11
# min    1.000000e+00
# 25%    5.500000e+06
# 50%    3.048000e+08
# 75%    5.005000e+11
# max    1.852000e+12

# %% [markdown]
# Para desacernos de los espacios NaN:<br>
#     **df.dropna()** elimina las filas que tengas datos NaN <br>
# **df.fillna(0)** sustituye los valores NaN por 0

# %% [markdown]
# ## Filtrado de datos
# **Filtrado de una o varias columnas**

# %%
df["MICRONES"]
# Out:
# 0          0,001
# 1              1
# 2           1000
# 3          10000
# 4        1000000
# 5     1000000000
# 6          25400
# 7         304800
# 8         914400
# 9     1609344000
# 10    1852000000
# Name: MICRONES, dtype: object

# %%
df[["METROS","KILOMETROS"]]
# Out:
#          METROS      KILOMETROS
# 0   0,000000001  0,000000000001
# 1      0,000001     0,000000001
# 2         0,001        0,000001
# 3          0,01         0,00001
# 4             1           0,001
# 5          1000               1
# 6        0,0254        0,000025
# 7        0,3048        0,000305
# 8        0,9144        0,000914
# 9      1609,344        1,609344
# 10         1852           1,852

# %% [markdown]
# ## Filtrado de datos
# **Filtrado de una o varias filas**

# %%
df = pd.read_csv("tablas.csv", delimiter=";", index_col="LONGITUD")

# %%
df.head()
# Out:
#              NANOMETROS MICRONES MILIMETROS CENTIMETROS       METROS  \
# LONGITUD
# NANOMETROS            1    0,001   0,000001   0,0000001  0,000000001
# MICRONES           1000        1      0,001      0,0001     0,000001
# MILIMETROS      1000000     1000          1         0,1        0,001
# CENTIMETROS    10000000    10000         10           1         0,01
# METROS       1000000000  1000000       1000         100            1
#
#                  KILOMETROS           PULGADAS              PIES  \
# LONGITUD
# NANOMETROS   0,000000000001  0,000000039370079  0,00000000328084
# MICRONES        0,000000001           0,000039          0,000003
# MILIMETROS         0,000001            0,03937          0,003281
# CENTIMETROS         0,00001           0,393701          0,032808
# METROS                0,001           39,37008           3,28084
#
#                         YARDAS             MILLAS    MILLAS_NAUTICAS
# LONGITUD
# ...

# %% [markdown]
# **iloc[]** permite filtrar por indice de fila

# %%
df.iloc[0:3]
# Out:
#             NANOMETROS MICRONES MILIMETROS CENTIMETROS       METROS  \
# LONGITUD
# NANOMETROS           1    0,001   0,000001   0,0000001  0,000000001
# MICRONES          1000        1      0,001      0,0001     0,000001
# MILIMETROS     1000000     1000          1         0,1        0,001
#
#                 KILOMETROS           PULGADAS              PIES  \
# LONGITUD
# NANOMETROS  0,000000000001  0,000000039370079  0,00000000328084
# MICRONES       0,000000001           0,000039          0,000003
# MILIMETROS        0,000001            0,03937          0,003281
#
#                        YARDAS             MILLAS    MILLAS_NAUTICAS
# LONGITUD
# NANOMETROS  0,000000001093613  0,000000000000621   0,00000000000054
# MICRONES             0,000001  0,000000000621371  0,000000000539957
# MILIMETROS           0,001094  0,000000621371192  0,000000539956803

# %%
df.iloc[[0,2,4]]
# Out:
#             NANOMETROS MICRONES MILIMETROS CENTIMETROS       METROS  \
# LONGITUD
# NANOMETROS           1    0,001   0,000001   0,0000001  0,000000001
# MILIMETROS     1000000     1000          1         0,1        0,001
# METROS      1000000000  1000000       1000         100            1
#
#                 KILOMETROS           PULGADAS              PIES  \
# LONGITUD
# NANOMETROS  0,000000000001  0,000000039370079  0,00000000328084
# MILIMETROS        0,000001            0,03937          0,003281
# METROS               0,001           39,37008           3,28084
#
#                        YARDAS             MILLAS    MILLAS_NAUTICAS
# LONGITUD
# NANOMETROS  0,000000001093613  0,000000000000621   0,00000000000054
# MILIMETROS           0,001094  0,000000621371192  0,000000539956803
# METROS               1,093613           0,000621            0,00054

# %%
df = pd.read_csv("tablas.csv", delimiter=";")

# %%
df.loc[[1,5]]
# Out:
#      LONGITUD     NANOMETROS    MICRONES MILIMETROS CENTIMETROS    METROS  \
# 1    MICRONES           1000           1      0,001      0,0001  0,000001
# 5  KILOMETROS  1000000000000  1000000000    1000000      100000      1000
#
#     KILOMETROS  PULGADAS      PIES    YARDAS             MILLAS  \
# 1  0,000000001  0,000039  0,000003  0,000001  0,000000000621371
# 5            1  39370,08   3280,84  1093,613           0,621371
#
#      MILLAS_NAUTICAS
# 1  0,000000000539957
# 5           0,539957

# %% [markdown]
# # **Filtrado de filas x columnas**

# %%
df.head()
# Out:
#       LONGITUD  NANOMETROS MICRONES MILIMETROS CENTIMETROS       METROS  \
# 0   NANOMETROS           1    0,001   0,000001   0,0000001  0,000000001
# 1     MICRONES        1000        1      0,001      0,0001     0,000001
# 2   MILIMETROS     1000000     1000          1         0,1        0,001
# 3  CENTIMETROS    10000000    10000         10           1         0,01
# 4       METROS  1000000000  1000000       1000         100            1
#
#        KILOMETROS           PULGADAS              PIES             YARDAS  \
# 0  0,000000000001  0,000000039370079  0,00000000328084  0,000000001093613
# 1     0,000000001           0,000039          0,000003           0,000001
# 2        0,000001            0,03937          0,003281           0,001094
# 3         0,00001           0,393701          0,032808           0,010936
# 4           0,001           39,37008           3,28084           1,093613
#
#               MILLAS    MILLAS_NAUTICAS
# 0  0,000000000000621   0,00000000000054
# ...

# %%
df.loc[2,"MICRONES"]
# Out:
# '1000'

# %%
df.loc[[3,4],["CENTIMETROS"]]
# Out:
#   CENTIMETROS
# 3           1
# 4         100

# %%
df.loc[[3,4],["CENTIMETROS", "METROS"]]
# Out:
#   CENTIMETROS METROS
# 3           1   0,01
# 4         100      1

# %% [markdown]
# # Filtrado por condiciones

# %%
df[float(df["CENTIMETROS"]) <= 1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-0c1797b9064f> in <module>
# ----> 1 df[float(df["CENTIMETROS"]) <= 1]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     127         if len(self) == 1:
#     128             return converter(self.iloc[0])
# --> 129         raise TypeError(f"cannot convert the series to {converter}")
#     130
#     131     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'float'>

# %%
a = df.loc[2,"MILLAS_NAUTICAS"]

# %%
a
# Out:
# '0,000000539956803'

# %%
a = a.replace(',', ".")

# %%
a
# Out:
# '0.000000539956803'

# %%
type(a)
# Out:
# str

# %%
#import numpy as np

# %%
a = float(a)

# %%
type(a)
# Out:
# float

# %%
a
# Out:
# 5.39956803e-07

# %%
# a = np.format_float_positional(a,trim='-')
a = a + 1

# %%
a
# Out:
# 1.000000539956803

# %%
# Out:
# str
